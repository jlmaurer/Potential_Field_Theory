# %% [markdown]
# # Lab N: [Title]
#
# | | |
# |---|---|
# | **Module** | MN — [Module Name] |
# | **Estimated time** | ~2.5 hours |
# | **Prerequisites** | [List lectures and homework sections] |
# | **Textbook** | Blakely Ch. X–Y; lecture notes MN |
#
# ---
#
# ## Learning Outcomes
#
# By the end of this lab you will be able to:
#
# 1. [Outcome 1 — use a measurable verb: *implement*, *compute*, *compare*, *explain*]
# 2. [Outcome 2]
# 3. [Outcome 3]
# 4. [Outcome 4]
#
# ---
#
# ## How to use this notebook
#
# Cells are tagged in their first line:
#
# - **`[PROVIDED]`** — run as-is, do not modify
# - **`[IMPLEMENT]`** — replace `raise NotImplementedError` with correct code
# - **`[VALIDATE]`** — run to check your work; prints ✓ PASS or ✗ FAIL
# - **`[EXPLORE]`** — starting point; modify freely to answer the question above
#
# Markdown cells with **Your response:** are written-answer questions.
# Write directly in the notebook — these are graded.
#
# Need a hint? Run `print(hints['key'])` in any code cell.
# Hint keys are listed at the start of each Part.

# %% [markdown]
# ## Background
#
# [2–3 paragraphs. Provide just enough theory that a student who did the reading
# can orient themselves. State the key equations that will be used — do not derive
# them here; point to the lecture notes and textbook for derivations.
#
# Example equation block:]
#
# The gravitational potential of a point mass $m$ at position $\mathbf{r}'$,
# evaluated at $\mathbf{r}$, is
#
# $$
# U(\mathbf{r}) = -\frac{Gm}{|\mathbf{r} - \mathbf{r}'|}
# $$
#
# where $G = 6.674 \times 10^{-11}\,\mathrm{N\,m^2\,kg^{-2}}$ is the
# gravitational constant (Blakely eq. X.X).
#
# [Continue with 1–2 more key relations specific to this lab.]

# %%
# [PROVIDED] ──────────────────────────────────────────────────────────────────
# Imports and constants. Run this cell first.

import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate, linalg

# Physical constants
G = 6.674e-11          # gravitational constant, N m^2 kg^-2
# [Add other constants relevant to this lab]

# Plotting defaults
plt.rcParams.update({
    'figure.dpi': 120,
    'axes.grid': True,
    'grid.alpha': 0.3,
})

print('Setup complete.')

# %%
# [PROVIDED] ──────────────────────────────────────────────────────────────────
# Hint dictionary. Access hints with:  print(hints['key'])
# Keys are listed at the start of each Part.

hints = {
    # Part 1
    'p1_DESCRIPTOR': (
        "[Physical intuition or equation reference — NOT code. "
        "Example: 'Outside the sphere, all mass acts as if at the center. "
        "See Blakely eq. 3.4. What is the relevant distance r?']"
    ),
    # Part 2
    'p2_DESCRIPTOR': (
        "[Hint for Part 2]"
    ),
    # Part 3
    'p3_DESCRIPTOR': (
        "[Hint for Part 3]"
    ),
}

# Example: print(hints['p1_DESCRIPTOR'])

# %% [markdown]
# ---
# ## Part 1: [Topic] *(Guided — ~40 min)*
#
# [One paragraph framing this part. What physical problem are we solving?
# What should students expect to see when they succeed?]
#
# **Available hints:** `p1_DESCRIPTOR`

# %%
# [IMPLEMENT] ─────────────────────────────────────────────────────────────────
# Tier 1: Complete the function below.
# The skeleton gives you the structure; fill in the physics.

def function_name(arg1, arg2, arg3):
    """
    One-line description of what the function computes.

    Parameters
    ----------
    arg1 : float or ndarray
        Description, including units.
    arg2 : float
        Description, including units.
    arg3 : float
        Description, including units.

    Returns
    -------
    result : float or ndarray
        Description, including units.

    Notes
    -----
    [Equation reference: Blakely eq. X.X or lecture notes MN, slide Y]
    [Any important sign conventions or special cases]
    """
    # Step 1: [description of what this step computes]
    # YOUR CODE HERE
    raise NotImplementedError

    # Step 2: [description]
    # YOUR CODE HERE
    raise NotImplementedError

    return result

# %%
# [VALIDATE] ──────────────────────────────────────────────────────────────────
# Run this cell to check function_name. Do not modify.

def _check(label, got, expected, rtol=1e-4, atol=0.0):
    if np.allclose(got, expected, rtol=rtol, atol=atol):
        print(f'  ✓ PASS  {label}')
    else:
        print(f'  ✗ FAIL  {label}')
        print(f'    expected: {np.asarray(expected)}')
        print(f'    got:      {np.asarray(got)}')

# Test 1: degenerate / limiting case
_check('[label for test 1]', function_name(...), EXPECTED_VALUE)

# Test 2: physically meaningful case
_check('[label for test 2]', function_name(...), EXPECTED_VALUE)

# Test 3: vector input
_check('[label for test 3]', function_name(...), EXPECTED_ARRAY)

# %% [markdown]
# ### Question 1.1
#
# [Physical question that requires thinking about the result, not just running code.
# Examples: 'Why does the field have this shape?', 'Where is the maximum/minimum
# and why?', 'How does the result change if you double the density?']
#
# **Your response:**
#
# > *(Write 3–5 sentences here. Replace this line.)*

# %%
# [EXPLORE] ───────────────────────────────────────────────────────────────────
# Plot [quantity] as a function of [variable].
# Requirements:
#   - x-axis: [quantity, units]
#   - y-axis: [quantity, units]
#   - Label the plot with a physically meaningful title
#   - Mark any special points (e.g., surface, maximum)

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 2: [Topic] *(Supported — ~50 min)*
#
# [Frame the problem. Less setup is given than Part 1 — you will need to make
# design choices. Hints are available if you get stuck.]
#
# **Available hints:** `p2_DESCRIPTOR`

# %%
# [PROVIDED] ──────────────────────────────────────────────────────────────────
# Data / setup for Part 2. Run as-is.

# [Generate or load data here. Use numpy random seeds for reproducibility.]
rng = np.random.default_rng(42)
# data = ...

# %%
# [IMPLEMENT] ─────────────────────────────────────────────────────────────────
# Tier 2: Implement the function from the docstring alone.
# No step-by-step skeleton is provided. Use hints if needed.

def another_function(arg1, arg2):
    """
    One-line description.

    Parameters
    ----------
    arg1 : ndarray, shape (N,)
        Description, units.
    arg2 : float
        Description, units.

    Returns
    -------
    result : ndarray, shape (N,)
        Description, units.

    Notes
    -----
    [Key equation / reference]
    """
    raise NotImplementedError

# %%
# [VALIDATE] ──────────────────────────────────────────────────────────────────

_check('[test label]', another_function(...), EXPECTED_VALUE)

# %% [markdown]
# ### Question 2.1
#
# [Question requiring comparison, trend analysis, or error assessment.]
#
# **Your response:**
#
# > *(Write 3–5 sentences here. Replace this line.)*

# %%
# [EXPLORE] ───────────────────────────────────────────────────────────────────
# Apply another_function to the dataset above and plot the result.
# Compare to [reference]. What do differences mean physically?

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Part 3: [Topic] *(Open — ~40 min)*
#
# [State the goal clearly but do not prescribe the approach. Students choose
# how to decompose the problem. Hints are available for the mathematically
# tricky parts only.]
#
# **Available hints:** `p3_DESCRIPTOR`

# %%
# [PROVIDED] ──────────────────────────────────────────────────────────────────
# Data for Part 3.

# [Minimal setup — just enough to remove file-loading friction]

# %%
# [EXPLORE] ───────────────────────────────────────────────────────────────────
# [State the goal. Leave this cell largely empty.]

# YOUR CODE HERE

# %% [markdown]
# ### Question 3.1
#
# [Open-ended interpretation question. Should require the student to connect
# the numerical result back to the physical setting.]
#
# **Your response:**
#
# > *(Write 3–5 sentences here. Replace this line.)*

# %% [markdown]
# ---
# ## Synthesis
#
# Answer the following questions in complete sentences. These questions draw
# across all three Parts and require physical reasoning, not just computation.
#
# ### S1
# [Cross-cutting question — connects Parts 1 and 2 or all three. Often a
# 'why does this make sense?' question.]
#
# **Your response:**
#
# > *(Write 4–6 sentences.)*
#
# ### S2
# [Limitation or assumption question. 'What assumptions did we make in Part X
# that would break down in a real-world scenario?']
#
# **Your response:**
#
# > *(Write 4–6 sentences.)*
#
# ### S3
# [Forward-looking question. 'How would you modify the approach in Part 2 to
# handle [more complex scenario]? What additional data would you need?']
#
# **Your response:**
#
# > *(Write 4–6 sentences.)*

# %% [markdown]
# ---
# ## Extensions *(optional)*
#
# These are for students who finish early or want to go deeper. They will not
# be graded unless explicitly stated by the instructor.
#
# ### E1: [Harder version of a core task]
# [Description. Should genuinely increase difficulty, not just add more steps.]
#
# ### E2: [Connection to real data or a published result]
# [Description. e.g., 'Compare your result to Figure X in [paper]. Where do
# the differences come from?']

# %%
# [EXPLORE] ───────────────────────────────────────────────────────────────────
# Extension workspace. Add cells as needed.

# YOUR CODE HERE
